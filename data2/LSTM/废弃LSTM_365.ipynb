# %%
import torch
from torch import nn
from model import BiLSTM_Deep
import numpy as np
import pandas as pd
import random
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
train_data_path = "../../train_hourly.csv"
test_data_path = "../../test_hourly.csv"

# %%
input_hours = 90 * 24       # 输入序列长度（90天）
output_hours = 365 * 24

use_cols = [
    'Global_active_power','Global_reactive_power',
    'Global_intensity','Sub_metering_1',
    'Sub_metering_2','Sub_metering_3',
    'sub_metering_remainder'
]

def load_hourly(path):
    df = pd.read_csv(path, parse_dates=['DateTime'])
    df.sort_values('DateTime', inplace=True)
    df.reset_index(drop=True, inplace=True)

    # 计算 sub_metering_remainder
    df["sub_metering_remainder"] = (
        df["Global_active_power"] * 1000 / 60
        - df["Sub_metering_1"]
        - df["Sub_metering_2"]
        - df["Sub_metering_3"]
    ).clip(lower=0)

    df = df[['DateTime'] + use_cols].copy()
    df.ffill(inplace=True)
    df.bfill(inplace=True)
    return df

train_df = load_hourly(train_data_path)
test_df  = load_hourly(test_data_path) 


full_df = pd.concat([train_df, test_df], ignore_index=True)

# ========= 标准化 ========= #
# scaler = MinMaxScaler()
# scaled = scaler.fit_transform(full_df[use_cols])
# target = scaled[:, 0]  # 目标值：Global_active_power
scaled = full_df[use_cols].values  # 直接使用原始值
target = scaled[:, 0]


# ========= 滑动窗口构造函数 ========= #
def build_samples(data, target, input_len, output_len, step=1):
    X, y = [], []
    for i in range(input_len, len(data) - output_len + 1, step):
        X.append(data[i - input_len:i])
        y.append(target[i:i + output_len])
    return np.array(X), np.array(y)

# ========= 构建样本 ========= #
X_all, y_all = build_samples(scaled, target, input_hours, output_hours, step=1)


# ========= 拆分 train / test ========= #
split_index = len(train_df) - input_hours  # 同样逻辑保证 test 在真实 test 部分
X_train = X_all[:split_index]
y_train = y_all[:split_index]
X_test  = X_all[split_index:]
y_test  = y_all[split_index:]


print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_test  shape: {X_test.shape}")
print(f"y_test  shape: {y_test.shape}")
# Out:
# X_train shape: (15751, 2160, 7)
# y_train shape: (15751, 8760)
# X_test  shape: (7919, 2160, 7)
# y_test  shape: (7919, 8760)

# %%
from torch.utils.data import TensorDataset, DataLoader, random_split
import matplotlib.pyplot as plt
import os

device = torch.device("cuda:3" if torch.cuda.is_available() else "cpu")
batch_size = 256

train_ds = TensorDataset(
    torch.tensor(X_train, dtype=torch.float32),
    torch.tensor(y_train, dtype=torch.float32)
)
val_size = int(len(train_ds) * 0.2)
train_size = len(train_ds) - val_size
train_subset, val_subset = random_split(train_ds, [train_size, val_size])

train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)

# %%
# 保存所有 loss 用于计算平均曲线
all_train_losses = []
all_val_losses = []
mae_list = []
mse_list = []

for run in range(1, 6):
    print(f"\n=== Run {run} ===")
    SEED = 42 + run  # 每组不同 seed
    torch.manual_seed(SEED)
    np.random.seed(SEED)
    random.seed(SEED)
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    model = BiLSTM_Deep(
        input_size=7,
        hidden_size=256,
        output_len=8760,
        num_layers=2,
        dropout=0.3
    ).to(device)

    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=3e-5)

    train_losses, val_losses = [], []
    best_val = float('inf')
    best_model = None
    best_mae = None
    best_mse = None
    patience = 10
    no_improve = 0

    for epoch in range(1, 101):
        model.train()
        total_train_loss = 0
        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)
            optimizer.zero_grad()
            pred = model(xb)
            loss = criterion(pred, yb)
            loss.backward()
            optimizer.step()
            total_train_loss += loss.item() * xb.size(0)
        avg_train = total_train_loss / len(train_subset)
        train_losses.append(avg_train)

        # 验证
        all_preds, all_gts = [], []
        model.eval()
        total_val_loss = 0
        with torch.no_grad():
            for xb, yb in val_loader:
                xb, yb = xb.to(device), yb.to(device)
                pred = model(xb)
                loss = criterion(pred, yb)
                total_val_loss += loss.item() * xb.size(0)
                all_preds.append(pred.cpu().numpy())
                all_gts.append(yb.cpu().numpy())


        all_preds = np.concatenate(all_preds, axis=0)
        all_gts = np.concatenate(all_gts, axis=0)

        avg_val = total_val_loss / len(val_subset)
        val_losses.append(avg_val)

        val_mae = mean_absolute_error(all_gts, all_preds)
        val_mse = mean_squared_error(all_gts, all_preds)
        print(f"Run {run} | Epoch {epoch:03d} | Train Loss: {avg_train:.6f} | "
          f"Val Loss: {avg_val:.6f} | MAE: {val_mae:.4f} | MSE: {val_mse:.4f}")

        # 保存最优模型
        if avg_val < best_val:
            best_val = avg_val
            best_model = model.state_dict()
            best_mae = val_mae
            best_mse = val_mse
            torch.save(best_model, f"output/models/pred365/run_{run}.pth")
            no_improve = 0
        else:
            no_improve += 1
            if no_improve >= patience:
                print(f"Early stopping at epoch {epoch}")
                break

    # 保存单组loss图
    plt.figure(figsize=(8, 5))
    plt.plot(train_losses, label="Train MSE")
    plt.plot(val_losses, label="Val MSE")
    plt.xlabel("Epoch")
    plt.ylabel("Loss (MSE)")
    plt.title(f"Loss Curve - Run {run}")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f"output/pics/loss/pred365/run_{run}.png", dpi=300)
    plt.close()

    # 收集供后续平均绘图
    all_train_losses.append(train_losses)
    all_val_losses.append(val_losses)
    mae_list.append(best_mae)
    mse_list.append(best_mse)

    
print("\n=== Final Evaluation over 5 Runs ===")
print(f"MAE: mean = {np.mean(mae_list):.4f}, std = {np.std(mae_list):.4f}")
print(f"MSE: mean = {np.mean(mse_list):.4f}, std = {np.std(mse_list):.4f}")
# Out:
# === Run 1 ===
# Run 1 | Epoch 001 | Train Loss: 1.963749 | Val Loss: 1.867196 | MAE: 1.0185 | MSE: 1.8672
# Run 1 | Epoch 002 | Train Loss: 1.552651 | Val Loss: 1.081694 | MAE: 0.7753 | MSE: 1.0817
# Run 1 | Epoch 003 | Train Loss: 1.066448 | Val Loss: 0.875352 | MAE: 0.7280 | MSE: 0.8754
# Run 1 | Epoch 004 | Train Loss: 0.957975 | Val Loss: 0.839419 | MAE: 0.7233 | MSE: 0.8394
# Run 1 | Epoch 005 | Train Loss: 0.924864 | Val Loss: 0.829388 | MAE: 0.7235 | MSE: 0.8294
# Run 1 | Epoch 006 | Train Loss: 0.907721 | Val Loss: 0.825476 | MAE: 0.7241 | MSE: 0.8255
# Run 1 | Epoch 007 | Train Loss: 0.896107 | Val Loss: 0.823207 | MAE: 0.7252 | MSE: 0.8232
# Run 1 | Epoch 008 | Train Loss: 0.887556 | Val Loss: 0.821993 | MAE: 0.7259 | MSE: 0.8220
# Run 1 | Epoch 009 | Train Loss: 0.880943 | Val Loss: 0.821030 | MAE: 0.7269 | MSE: 0.8210
# Run 1 | Epoch 010 | Train Loss: 0.875498 | Val Loss: 0.820452 | MAE: 0.7276 | MSE: 0.8205
# Run 1 | Epoch 011 | Train Loss: 0.871034 | Val Loss: 0.820025 | MAE: 0.7287 | MSE: 0.8200
# Run 1 | Epoch 012 | Train Loss: 0.867296 | Val Loss: 0.819759 | MAE: 0.7297 | MSE: 0.8198
# Run 1 | Epoch 013 | Train Loss: 0.864446 | Val Loss: 0.819642 | MAE: 0.7294 | MSE: 0.8196
# Run 1 | Epoch 014 | Train Loss: 0.861671 | Val Loss: 0.819489 | MAE: 0.7304 | MSE: 0.8195
# Run 1 | Epoch 015 | Train Loss: 0.859416 | Val Loss: 0.819395 | MAE: 0.7305 | MSE: 0.8194
# Run 1 | Epoch 016 | Train Loss: 0.857407 | Val Loss: 0.819330 | MAE: 0.7302 | MSE: 0.8193
# Run 1 | Epoch 017 | Train Loss: 0.855616 | Val Loss: 0.819243 | MAE: 0.7311 | MSE: 0.8192
# Run 1 | Epoch 018 | Train Loss: 0.853962 | Val Loss: 0.819162 | MAE: 0.7312 | MSE: 0.8192
# Run 1 | Epoch 019 | Train Loss: 0.852528 | Val Loss: 0.819149 | MAE: 0.7319 | MSE: 0.8191
# Run 1 | Epoch 020 | Train Loss: 0.851175 | Val Loss: 0.819072 | MAE: 0.7319 | MSE: 0.8191
# Run 1 | Epoch 021 | Train Loss: 0.850058 | Val Loss: 0.819130 | MAE: 0.7328 | MSE: 0.8191
# Run 1 | Epoch 022 | Train Loss: 0.848867 | Val Loss: 0.818968 | MAE: 0.7324 | MSE: 0.8190
# Run 1 | Epoch 023 | Train Loss: 0.847799 | Val Loss: 0.818905 | MAE: 0.7324 | MSE: 0.8189
# Run 1 | Epoch 024 | Train Loss: 0.846787 | Val Loss: 0.818859 | MAE: 0.7328 | MSE: 0.8189
# Run 1 | Epoch 025 | Train Loss: 0.845813 | Val Loss: 0.818633 | MAE: 0.7324 | MSE: 0.8186
# Run 1 | Epoch 026 | Train Loss: 0.844997 | Val Loss: 0.818459 | MAE: 0.7322 | MSE: 0.8185
# Run 1 | Epoch 027 | Train Loss: 0.843973 | Val Loss: 0.818065 | MAE: 0.7306 | MSE: 0.8181
# Run 1 | Epoch 028 | Train Loss: 0.843295 | Val Loss: 0.817981 | MAE: 0.7321 | MSE: 0.8180
# Run 1 | Epoch 029 | Train Loss: 0.842430 | Val Loss: 0.817629 | MAE: 0.7315 | MSE: 0.8176
# Run 1 | Epoch 030 | Train Loss: 0.841440 | Val Loss: 0.817545 | MAE: 0.7333 | MSE: 0.8175
# Run 1 | Epoch 031 | Train Loss: 0.840484 | Val Loss: 0.816732 | MAE: 0.7321 | MSE: 0.8167
# Run 1 | Epoch 032 | Train Loss: 0.839294 | Val Loss: 0.815829 | MAE: 0.7311 | MSE: 0.8158
# Run 1 | Epoch 033 | Train Loss: 0.838203 | Val Loss: 0.815015 | MAE: 0.7314 | MSE: 0.8150
# Run 1 | Epoch 034 | Train Loss: 0.836869 | Val Loss: 0.813700 | MAE: 0.7300 | MSE: 0.8137
# Run 1 | Epoch 035 | Train Loss: 0.835571 | Val Loss: 0.812767 | MAE: 0.7304 | MSE: 0.8128
# Run 1 | Epoch 036 | Train Loss: 0.833893 | Val Loss: 0.811071 | MAE: 0.7283 | MSE: 0.8111
# Run 1 | Epoch 037 | Train Loss: 0.832489 | Val Loss: 0.809385 | MAE: 0.7262 | MSE: 0.8094
# Run 1 | Epoch 038 | Train Loss: 0.830623 | Val Loss: 0.807671 | MAE: 0.7252 | MSE: 0.8077
# Run 1 | Epoch 039 | Train Loss: 0.828991 | Val Loss: 0.806254 | MAE: 0.7260 | MSE: 0.8063
# Run 1 | Epoch 040 | Train Loss: 0.826637 | Val Loss: 0.803232 | MAE: 0.7232 | MSE: 0.8032
# Run 1 | Epoch 041 | Train Loss: 0.823962 | Val Loss: 0.799810 | MAE: 0.7208 | MSE: 0.7998
# Run 1 | Epoch 042 | Train Loss: 0.820777 | Val Loss: 0.796519 | MAE: 0.7200 | MSE: 0.7965
# Run 1 | Epoch 043 | Train Loss: 0.817088 | Val Loss: 0.792441 | MAE: 0.7167 | MSE: 0.7924
# Run 1 | Epoch 044 | Train Loss: 0.813836 | Val Loss: 0.788402 | MAE: 0.7148 | MSE: 0.7884
# Run 1 | Epoch 045 | Train Loss: 0.810141 | Val Loss: 0.784773 | MAE: 0.7119 | MSE: 0.7848
# Run 1 | Epoch 046 | Train Loss: 0.806862 | Val Loss: 0.781771 | MAE: 0.7096 | MSE: 0.7818
# Run 1 | Epoch 047 | Train Loss: 0.804368 | Val Loss: 0.778878 | MAE: 0.7074 | MSE: 0.7789
# Run 1 | Epoch 048 | Train Loss: 0.801780 | Val Loss: 0.775878 | MAE: 0.7056 | MSE: 0.7759
# Run 1 | Epoch 049 | Train Loss: 0.798560 | Val Loss: 0.772622 | MAE: 0.7033 | MSE: 0.7726
# Run 1 | Epoch 050 | Train Loss: 0.795621 | Val Loss: 0.769791 | MAE: 0.7008 | MSE: 0.7698
# Run 1 | Epoch 051 | Train Loss: 0.793059 | Val Loss: 0.765861 | MAE: 0.6982 | MSE: 0.7659
# Run 1 | Epoch 052 | Train Loss: 0.789342 | Val Loss: 0.762271 | MAE: 0.6954 | MSE: 0.7623
# Run 1 | Epoch 053 | Train Loss: 0.786012 | Val Loss: 0.757977 | MAE: 0.6927 | MSE: 0.7580
# Run 1 | Epoch 054 | Train Loss: 0.781145 | Val Loss: 0.751045 | MAE: 0.6865 | MSE: 0.7510
# Run 1 | Epoch 055 | Train Loss: 0.773502 | Val Loss: 0.735944 | MAE: 0.6759 | MSE: 0.7359
# Run 1 | Epoch 056 | Train Loss: 0.758363 | Val Loss: 0.717743 | MAE: 0.6620 | MSE: 0.7177
# Run 1 | Epoch 057 | Train Loss: 0.746310 | Val Loss: 0.707554 | MAE: 0.6526 | MSE: 0.7076
# Run 1 | Epoch 058 | Train Loss: 0.735498 | Val Loss: 0.699910 | MAE: 0.6460 | MSE: 0.6999
# Run 1 | Epoch 059 | Train Loss: 0.728369 | Val Loss: 0.694640 | MAE: 0.6417 | MSE: 0.6946
# Run 1 | Epoch 060 | Train Loss: 0.723541 | Val Loss: 0.695691 | MAE: 0.6397 | MSE: 0.6957
# Run 1 | Epoch 061 | Train Loss: 0.723389 | Val Loss: 0.691503 | MAE: 0.6390 | MSE: 0.6915
# Run 1 | Epoch 062 | Train Loss: 0.719032 | Val Loss: 0.685898 | MAE: 0.6336 | MSE: 0.6859
# Run 1 | Epoch 063 | Train Loss: 0.716287 | Val Loss: 0.686221 | MAE: 0.6325 | MSE: 0.6862
# Run 1 | Epoch 064 | Train Loss: 0.713909 | Val Loss: 0.681247 | MAE: 0.6286 | MSE: 0.6812
# Run 1 | Epoch 065 | Train Loss: 0.727686 | Val Loss: 0.738665 | MAE: 0.6612 | MSE: 0.7387
# Run 1 | Epoch 066 | Train Loss: 0.807773 | Val Loss: 0.750820 | MAE: 0.6780 | MSE: 0.7508
# Run 1 | Epoch 067 | Train Loss: 0.755141 | Val Loss: 0.725022 | MAE: 0.6629 | MSE: 0.7250
# Run 1 | Epoch 068 | Train Loss: 0.743476 | Val Loss: 0.719668 | MAE: 0.6574 | MSE: 0.7197
# Run 1 | Epoch 069 | Train Loss: 0.737154 | Val Loss: 0.709200 | MAE: 0.6502 | MSE: 0.7092
# Run 1 | Epoch 070 | Train Loss: 0.731154 | Val Loss: 0.700252 | MAE: 0.6443 | MSE: 0.7003
# Run 1 | Epoch 071 | Train Loss: 0.732044 | Val Loss: 0.708379 | MAE: 0.6479 | MSE: 0.7084
# Run 1 | Epoch 072 | Train Loss: 0.728720 | Val Loss: 0.700230 | MAE: 0.6435 | MSE: 0.7002
# Run 1 | Epoch 073 | Train Loss: 0.723925 | Val Loss: 0.699276 | MAE: 0.6414 | MSE: 0.6993
# Run 1 | Epoch 074 | Train Loss: 0.721914 | Val Loss: 0.697075 | MAE: 0.6396 | MSE: 0.6971
# Early stopping at epoch 74
#
# === Run 2 ===
# Run 2 | Epoch 001 | Train Loss: 1.964108 | Val Loss: 1.867669 | MAE: 1.0187 | MSE: 1.8677
# Run 2 | Epoch 002 | Train Loss: 1.555698 | Val Loss: 1.087305 | MAE: 0.7755 | MSE: 1.0873
# Run 2 | Epoch 003 | Train Loss: 1.068331 | Val Loss: 0.873892 | MAE: 0.7281 | MSE: 0.8739
# Run 2 | Epoch 004 | Train Loss: 0.957253 | Val Loss: 0.838927 | MAE: 0.7228 | MSE: 0.8389
# Run 2 | Epoch 005 | Train Loss: 0.924584 | Val Loss: 0.828888 | MAE: 0.7236 | MSE: 0.8289
# Run 2 | Epoch 006 | Train Loss: 0.907323 | Val Loss: 0.825433 | MAE: 0.7238 | MSE: 0.8254
# Run 2 | Epoch 007 | Train Loss: 0.895726 | Val Loss: 0.823126 | MAE: 0.7252 | MSE: 0.8231
# Run 2 | Epoch 008 | Train Loss: 0.887343 | Val Loss: 0.821919 | MAE: 0.7260 | MSE: 0.8219
# Run 2 | Epoch 009 | Train Loss: 0.880786 | Val Loss: 0.821218 | MAE: 0.7264 | MSE: 0.8212
# Run 2 | Epoch 010 | Train Loss: 0.875383 | Val Loss: 0.820335 | MAE: 0.7284 | MSE: 0.8203
# Run 2 | Epoch 011 | Train Loss: 0.871027 | Val Loss: 0.820117 | MAE: 0.7281 | MSE: 0.8201
# Run 2 | Epoch 012 | Train Loss: 0.867555 | Val Loss: 0.819833 | MAE: 0.7289 | MSE: 0.8198
# Run 2 | Epoch 013 | Train Loss: 0.864454 | Val Loss: 0.819650 | MAE: 0.7293 | MSE: 0.8196
# Run 2 | Epoch 014 | Train Loss: 0.861748 | Val Loss: 0.819536 | MAE: 0.7298 | MSE: 0.8195
# Run 2 | Epoch 015 | Train Loss: 0.859570 | Val Loss: 0.819427 | MAE: 0.7312 | MSE: 0.8194
# Run 2 | Epoch 016 | Train Loss: 0.857532 | Val Loss: 0.819309 | MAE: 0.7304 | MSE: 0.8193
# Run 2 | Epoch 017 | Train Loss: 0.855807 | Val Loss: 0.819285 | MAE: 0.7314 | MSE: 0.8193
# Run 2 | Epoch 018 | Train Loss: 0.854082 | Val Loss: 0.819277 | MAE: 0.7317 | MSE: 0.8193
# Run 2 | Epoch 019 | Train Loss: 0.852682 | Val Loss: 0.819245 | MAE: 0.7323 | MSE: 0.8192
# Run 2 | Epoch 020 | Train Loss: 0.851279 | Val Loss: 0.819304 | MAE: 0.7330 | MSE: 0.8193
# Run 2 | Epoch 021 | Train Loss: 0.850038 | Val Loss: 0.819141 | MAE: 0.7326 | MSE: 0.8191
# Run 2 | Epoch 022 | Train Loss: 0.849021 | Val Loss: 0.818930 | MAE: 0.7314 | MSE: 0.8189
# Run 2 | Epoch 023 | Train Loss: 0.848072 | Val Loss: 0.819236 | MAE: 0.7336 | MSE: 0.8192
# Run 2 | Epoch 024 | Train Loss: 0.846836 | Val Loss: 0.818839 | MAE: 0.7321 | MSE: 0.8188
# Run 2 | Epoch 025 | Train Loss: 0.846046 | Val Loss: 0.818737 | MAE: 0.7321 | MSE: 0.8187
# Run 2 | Epoch 026 | Train Loss: 0.845105 | Val Loss: 0.818568 | MAE: 0.7314 | MSE: 0.8186
# Run 2 | Epoch 027 | Train Loss: 0.844324 | Val Loss: 0.818591 | MAE: 0.7324 | MSE: 0.8186
# Run 2 | Epoch 028 | Train Loss: 0.843646 | Val Loss: 0.818804 | MAE: 0.7339 | MSE: 0.8188
# Run 2 | Epoch 029 | Train Loss: 0.842815 | Val Loss: 0.818204 | MAE: 0.7318 | MSE: 0.8182
# Run 2 | Epoch 030 | Train Loss: 0.842105 | Val Loss: 0.818113 | MAE: 0.7328 | MSE: 0.8181
# Run 2 | Epoch 031 | Train Loss: 0.841203 | Val Loss: 0.817763 | MAE: 0.7320 | MSE: 0.8178
# Run 2 | Epoch 032 | Train Loss: 0.840337 | Val Loss: 0.817333 | MAE: 0.7317 | MSE: 0.8173
# Run 2 | Epoch 033 | Train Loss: 0.839675 | Val Loss: 0.816918 | MAE: 0.7315 | MSE: 0.8169
# Run 2 | Epoch 034 | Train Loss: 0.838735 | Val Loss: 0.816309 | MAE: 0.7314 | MSE: 0.8163
# Run 2 | Epoch 035 | Train Loss: 0.837802 | Val Loss: 0.815518 | MAE: 0.7308 | MSE: 0.8155
# Run 2 | Epoch 036 | Train Loss: 0.836548 | Val Loss: 0.814351 | MAE: 0.7293 | MSE: 0.8144
# Run 2 | Epoch 037 | Train Loss: 0.835236 | Val Loss: 0.813548 | MAE: 0.7301 | MSE: 0.8135
# Run 2 | Epoch 038 | Train Loss: 0.834002 | Val Loss: 0.812199 | MAE: 0.7288 | MSE: 0.8122
# Run 2 | Epoch 039 | Train Loss: 0.832575 | Val Loss: 0.811519 | MAE: 0.7304 | MSE: 0.8115
# Run 2 | Epoch 040 | Train Loss: 0.831208 | Val Loss: 0.809427 | MAE: 0.7272 | MSE: 0.8094
# Run 2 | Epoch 041 | Train Loss: 0.829551 | Val Loss: 0.807498 | MAE: 0.7248 | MSE: 0.8075
# Run 2 | Epoch 042 | Train Loss: 0.827812 | Val Loss: 0.805474 | MAE: 0.7241 | MSE: 0.8055
# Run 2 | Epoch 043 | Train Loss: 0.825248 | Val Loss: 0.802868 | MAE: 0.7240 | MSE: 0.8029
# Run 2 | Epoch 044 | Train Loss: 0.822108 | Val Loss: 0.798103 | MAE: 0.7184 | MSE: 0.7981
# Run 2 | Epoch 045 | Train Loss: 0.818259 | Val Loss: 0.793044 | MAE: 0.7162 | MSE: 0.7930
# Run 2 | Epoch 046 | Train Loss: 0.813556 | Val Loss: 0.788795 | MAE: 0.7162 | MSE: 0.7888
# Run 2 | Epoch 047 | Train Loss: 0.809325 | Val Loss: 0.783402 | MAE: 0.7111 | MSE: 0.7834
# Run 2 | Epoch 048 | Train Loss: 0.805425 | Val Loss: 0.779275 | MAE: 0.7076 | MSE: 0.7793
# Run 2 | Epoch 049 | Train Loss: 0.801684 | Val Loss: 0.775676 | MAE: 0.7054 | MSE: 0.7757
# Run 2 | Epoch 050 | Train Loss: 0.798425 | Val Loss: 0.771911 | MAE: 0.7019 | MSE: 0.7719
# Run 2 | Epoch 051 | Train Loss: 0.795058 | Val Loss: 0.768479 | MAE: 0.6988 | MSE: 0.7685
# Run 2 | Epoch 052 | Train Loss: 0.791537 | Val Loss: 0.766000 | MAE: 0.6967 | MSE: 0.7660
# Run 2 | Epoch 053 | Train Loss: 0.788926 | Val Loss: 0.760922 | MAE: 0.6927 | MSE: 0.7609
# Run 2 | Epoch 054 | Train Loss: 0.784180 | Val Loss: 0.755962 | MAE: 0.6894 | MSE: 0.7560
# Run 2 | Epoch 055 | Train Loss: 0.778814 | Val Loss: 0.746045 | MAE: 0.6830 | MSE: 0.7460
# Run 2 | Epoch 056 | Train Loss: 0.766527 | Val Loss: 0.723488 | MAE: 0.6661 | MSE: 0.7235
# Run 2 | Epoch 057 | Train Loss: 0.749425 | Val Loss: 0.715789 | MAE: 0.6574 | MSE: 0.7158
# Run 2 | Epoch 058 | Train Loss: 0.738140 | Val Loss: 0.696737 | MAE: 0.6439 | MSE: 0.6967
# Run 2 | Epoch 059 | Train Loss: 0.731213 | Val Loss: 0.696309 | MAE: 0.6428 | MSE: 0.6963
# Run 2 | Epoch 060 | Train Loss: 0.725788 | Val Loss: 0.688375 | MAE: 0.6345 | MSE: 0.6884
# Run 2 | Epoch 061 | Train Loss: 0.722011 | Val Loss: 0.689065 | MAE: 0.6346 | MSE: 0.6891
# Run 2 | Epoch 062 | Train Loss: 0.719485 | Val Loss: 0.687281 | MAE: 0.6328 | MSE: 0.6873
# Run 2 | Epoch 063 | Train Loss: 0.720847 | Val Loss: 0.686728 | MAE: 0.6330 | MSE: 0.6867
# Run 2 | Epoch 064 | Train Loss: 0.715592 | Val Loss: 0.683207 | MAE: 0.6300 | MSE: 0.6832
# Run 2 | Epoch 065 | Train Loss: 0.711939 | Val Loss: 0.688273 | MAE: 0.6321 | MSE: 0.6883
# Run 2 | Epoch 066 | Train Loss: 0.710798 | Val Loss: 0.685391 | MAE: 0.6295 | MSE: 0.6854
# Run 2 | Epoch 067 | Train Loss: 0.709407 | Val Loss: 0.680095 | MAE: 0.6249 | MSE: 0.6801
# Run 2 | Epoch 068 | Train Loss: 0.707524 | Val Loss: 0.684289 | MAE: 0.6286 | MSE: 0.6843
# Run 2 | Epoch 069 | Train Loss: 0.706023 | Val Loss: 0.678414 | MAE: 0.6245 | MSE: 0.6784
# Run 2 | Epoch 070 | Train Loss: 0.722666 | Val Loss: 0.701667 | MAE: 0.6422 | MSE: 0.7017
# Run 2 | Epoch 071 | Train Loss: 0.733215 | Val Loss: 0.698391 | MAE: 0.6423 | MSE: 0.6984
# Run 2 | Epoch 072 | Train Loss: 0.814441 | Val Loss: 0.819364 | MAE: 0.7230 | MSE: 0.8194
# Run 2 | Epoch 073 | Train Loss: 0.811598 | Val Loss: 0.795170 | MAE: 0.7097 | MSE: 0.7952
# Run 2 | Epoch 074 | Train Loss: 0.798576 | Val Loss: 0.769022 | MAE: 0.6953 | MSE: 0.7690
# Run 2 | Epoch 075 | Train Loss: 0.782279 | Val Loss: 0.755407 | MAE: 0.6855 | MSE: 0.7554
# Run 2 | Epoch 076 | Train Loss: 0.772531 | Val Loss: 0.746889 | MAE: 0.6798 | MSE: 0.7469
# Run 2 | Epoch 077 | Train Loss: 0.766590 | Val Loss: 0.741923 | MAE: 0.6739 | MSE: 0.7419
# Run 2 | Epoch 078 | Train Loss: 0.762026 | Val Loss: 0.737305 | MAE: 0.6710 | MSE: 0.7373
# Run 2 | Epoch 079 | Train Loss: 0.758753 | Val Loss: 0.734678 | MAE: 0.6680 | MSE: 0.7347
# Early stopping at epoch 79
#
# === Run 3 ===
# Run 3 | Epoch 001 | Train Loss: 1.964306 | Val Loss: 1.865114 | MAE: 1.0175 | MSE: 1.8651
# Run 3 | Epoch 002 | Train Loss: 1.548628 | Val Loss: 1.080374 | MAE: 0.7736 | MSE: 1.0804
# Run 3 | Epoch 003 | Train Loss: 1.066532 | Val Loss: 0.874778 | MAE: 0.7273 | MSE: 0.8748
# Run 3 | Epoch 004 | Train Loss: 0.957802 | Val Loss: 0.838544 | MAE: 0.7233 | MSE: 0.8385
# Run 3 | Epoch 005 | Train Loss: 0.925061 | Val Loss: 0.829001 | MAE: 0.7232 | MSE: 0.8290
# Run 3 | Epoch 006 | Train Loss: 0.907328 | Val Loss: 0.825142 | MAE: 0.7240 | MSE: 0.8251
# Run 3 | Epoch 007 | Train Loss: 0.895553 | Val Loss: 0.822757 | MAE: 0.7256 | MSE: 0.8228
# Run 3 | Epoch 008 | Train Loss: 0.887261 | Val Loss: 0.821684 | MAE: 0.7263 | MSE: 0.8217
# Run 3 | Epoch 009 | Train Loss: 0.880474 | Val Loss: 0.820901 | MAE: 0.7271 | MSE: 0.8209
# Run 3 | Epoch 010 | Train Loss: 0.875336 | Val Loss: 0.820325 | MAE: 0.7282 | MSE: 0.8203
# Run 3 | Epoch 011 | Train Loss: 0.870930 | Val Loss: 0.820072 | MAE: 0.7282 | MSE: 0.8201
# Run 3 | Epoch 012 | Train Loss: 0.867301 | Val Loss: 0.819725 | MAE: 0.7295 | MSE: 0.8197
# Run 3 | Epoch 013 | Train Loss: 0.864092 | Val Loss: 0.819593 | MAE: 0.7295 | MSE: 0.8196
# Run 3 | Epoch 014 | Train Loss: 0.861466 | Val Loss: 0.819471 | MAE: 0.7306 | MSE: 0.8195
# Run 3 | Epoch 015 | Train Loss: 0.859102 | Val Loss: 0.819369 | MAE: 0.7308 | MSE: 0.8194
# Run 3 | Epoch 016 | Train Loss: 0.857253 | Val Loss: 0.819266 | MAE: 0.7298 | MSE: 0.8193
# Run 3 | Epoch 017 | Train Loss: 0.855339 | Val Loss: 0.819230 | MAE: 0.7313 | MSE: 0.8192
# Run 3 | Epoch 018 | Train Loss: 0.853618 | Val Loss: 0.819132 | MAE: 0.7308 | MSE: 0.8191
# Run 3 | Epoch 019 | Train Loss: 0.852167 | Val Loss: 0.819089 | MAE: 0.7320 | MSE: 0.8191
# Run 3 | Epoch 020 | Train Loss: 0.850824 | Val Loss: 0.819053 | MAE: 0.7323 | MSE: 0.8191
# Run 3 | Epoch 021 | Train Loss: 0.849740 | Val Loss: 0.819028 | MAE: 0.7327 | MSE: 0.8190
# Run 3 | Epoch 022 | Train Loss: 0.848430 | Val Loss: 0.819002 | MAE: 0.7332 | MSE: 0.8190
# Run 3 | Epoch 023 | Train Loss: 0.847390 | Val Loss: 0.818900 | MAE: 0.7332 | MSE: 0.8189
# Run 3 | Epoch 024 | Train Loss: 0.846451 | Val Loss: 0.818604 | MAE: 0.7323 | MSE: 0.8186
# Run 3 | Epoch 025 | Train Loss: 0.845455 | Val Loss: 0.818417 | MAE: 0.7322 | MSE: 0.8184
# Run 3 | Epoch 026 | Train Loss: 0.844652 | Val Loss: 0.818059 | MAE: 0.7309 | MSE: 0.8181
# Run 3 | Epoch 027 | Train Loss: 0.843513 | Val Loss: 0.817857 | MAE: 0.7315 | MSE: 0.8179
# Run 3 | Epoch 028 | Train Loss: 0.842854 | Val Loss: 0.817650 | MAE: 0.7321 | MSE: 0.8176
# Run 3 | Epoch 029 | Train Loss: 0.842002 | Val Loss: 0.817207 | MAE: 0.7314 | MSE: 0.8172
# Run 3 | Epoch 030 | Train Loss: 0.840864 | Val Loss: 0.816592 | MAE: 0.7306 | MSE: 0.8166
# Run 3 | Epoch 031 | Train Loss: 0.839946 | Val Loss: 0.816023 | MAE: 0.7304 | MSE: 0.8160
# Run 3 | Epoch 032 | Train Loss: 0.838983 | Val Loss: 0.815344 | MAE: 0.7298 | MSE: 0.8153
# Run 3 | Epoch 033 | Train Loss: 0.837877 | Val Loss: 0.814689 | MAE: 0.7307 | MSE: 0.8147
# Run 3 | Epoch 034 | Train Loss: 0.836668 | Val Loss: 0.813751 | MAE: 0.7303 | MSE: 0.8138
# Run 3 | Epoch 035 | Train Loss: 0.835313 | Val Loss: 0.812472 | MAE: 0.7286 | MSE: 0.8125
# Run 3 | Epoch 036 | Train Loss: 0.834261 | Val Loss: 0.811216 | MAE: 0.7276 | MSE: 0.8112
# Run 3 | Epoch 037 | Train Loss: 0.832639 | Val Loss: 0.810201 | MAE: 0.7283 | MSE: 0.8102
# Run 3 | Epoch 038 | Train Loss: 0.831021 | Val Loss: 0.808166 | MAE: 0.7254 | MSE: 0.8082
# Run 3 | Epoch 039 | Train Loss: 0.829202 | Val Loss: 0.805967 | MAE: 0.7246 | MSE: 0.8060
# Run 3 | Epoch 040 | Train Loss: 0.826986 | Val Loss: 0.803972 | MAE: 0.7248 | MSE: 0.8040
# Run 3 | Epoch 041 | Train Loss: 0.824484 | Val Loss: 0.800858 | MAE: 0.7208 | MSE: 0.8009
# Run 3 | Epoch 042 | Train Loss: 0.821318 | Val Loss: 0.796564 | MAE: 0.7184 | MSE: 0.7966
# Run 3 | Epoch 043 | Train Loss: 0.817571 | Val Loss: 0.792398 | MAE: 0.7156 | MSE: 0.7924
# Run 3 | Epoch 044 | Train Loss: 0.818663 | Val Loss: 0.792442 | MAE: 0.7158 | MSE: 0.7924
# Run 3 | Epoch 045 | Train Loss: 0.812977 | Val Loss: 0.786036 | MAE: 0.7096 | MSE: 0.7860
# Run 3 | Epoch 046 | Train Loss: 0.808935 | Val Loss: 0.783218 | MAE: 0.7107 | MSE: 0.7832
# Run 3 | Epoch 047 | Train Loss: 0.805201 | Val Loss: 0.779499 | MAE: 0.7077 | MSE: 0.7795
# Run 3 | Epoch 048 | Train Loss: 0.802194 | Val Loss: 0.776095 | MAE: 0.7037 | MSE: 0.7761
# Run 3 | Epoch 049 | Train Loss: 0.799227 | Val Loss: 0.773242 | MAE: 0.7031 | MSE: 0.7732
# Run 3 | Epoch 050 | Train Loss: 0.795907 | Val Loss: 0.770166 | MAE: 0.7010 | MSE: 0.7702
# Run 3 | Epoch 051 | Train Loss: 0.793053 | Val Loss: 0.766390 | MAE: 0.6977 | MSE: 0.7664
# Run 3 | Epoch 052 | Train Loss: 0.789587 | Val Loss: 0.762567 | MAE: 0.6947 | MSE: 0.7626
# Run 3 | Epoch 053 | Train Loss: 0.786231 | Val Loss: 0.758050 | MAE: 0.6905 | MSE: 0.7580
# Run 3 | Epoch 054 | Train Loss: 0.781684 | Val Loss: 0.752222 | MAE: 0.6866 | MSE: 0.7522
# Run 3 | Epoch 055 | Train Loss: 0.775331 | Val Loss: 0.740708 | MAE: 0.6788 | MSE: 0.7407
# Run 3 | Epoch 056 | Train Loss: 0.763364 | Val Loss: 0.723632 | MAE: 0.6652 | MSE: 0.7236
# Run 3 | Epoch 057 | Train Loss: 0.753678 | Val Loss: 0.716149 | MAE: 0.6575 | MSE: 0.7161
# Run 3 | Epoch 058 | Train Loss: 0.741099 | Val Loss: 0.701106 | MAE: 0.6472 | MSE: 0.7011
# Run 3 | Epoch 059 | Train Loss: 0.731890 | Val Loss: 0.696766 | MAE: 0.6426 | MSE: 0.6968
# Run 3 | Epoch 060 | Train Loss: 0.726642 | Val Loss: 0.692408 | MAE: 0.6397 | MSE: 0.6924
# Run 3 | Epoch 061 | Train Loss: 0.722621 | Val Loss: 0.701132 | MAE: 0.6405 | MSE: 0.7011
# Run 3 | Epoch 062 | Train Loss: 0.720987 | Val Loss: 0.688350 | MAE: 0.6341 | MSE: 0.6883
# Run 3 | Epoch 063 | Train Loss: 0.717466 | Val Loss: 0.688061 | MAE: 0.6314 | MSE: 0.6881
# Run 3 | Epoch 064 | Train Loss: 0.758095 | Val Loss: 0.727305 | MAE: 0.6613 | MSE: 0.7273
# Run 3 | Epoch 065 | Train Loss: 0.746215 | Val Loss: 0.711133 | MAE: 0.6509 | MSE: 0.7111
# Run 3 | Epoch 066 | Train Loss: 0.736577 | Val Loss: 0.707219 | MAE: 0.6485 | MSE: 0.7072
# Run 3 | Epoch 067 | Train Loss: 0.731340 | Val Loss: 0.701907 | MAE: 0.6449 | MSE: 0.7019
# Run 3 | Epoch 068 | Train Loss: 0.728199 | Val Loss: 0.699250 | MAE: 0.6421 | MSE: 0.6993
# Run 3 | Epoch 069 | Train Loss: 0.723904 | Val Loss: 0.696260 | MAE: 0.6396 | MSE: 0.6963
# Run 3 | Epoch 070 | Train Loss: 0.721580 | Val Loss: 0.695647 | MAE: 0.6397 | MSE: 0.6956
# Run 3 | Epoch 071 | Train Loss: 0.718698 | Val Loss: 0.689452 | MAE: 0.6349 | MSE: 0.6895
# Run 3 | Epoch 072 | Train Loss: 0.716242 | Val Loss: 0.687214 | MAE: 0.6341 | MSE: 0.6872
# Run 3 | Epoch 073 | Train Loss: 0.712566 | Val Loss: 0.684234 | MAE: 0.6313 | MSE: 0.6842
# Run 3 | Epoch 074 | Train Loss: 0.709102 | Val Loss: 0.679690 | MAE: 0.6270 | MSE: 0.6797
# Run 3 | Epoch 075 | Train Loss: 0.706560 | Val Loss: 0.679741 | MAE: 0.6272 | MSE: 0.6797
# Run 3 | Epoch 076 | Train Loss: 0.705129 | Val Loss: 0.680326 | MAE: 0.6266 | MSE: 0.6803
# Run 3 | Epoch 077 | Train Loss: 0.713960 | Val Loss: 0.680342 | MAE: 0.6295 | MSE: 0.6803
# Run 3 | Epoch 078 | Train Loss: 0.706090 | Val Loss: 0.678178 | MAE: 0.6263 | MSE: 0.6782
# Run 3 | Epoch 079 | Train Loss: 0.703753 | Val Loss: 0.677150 | MAE: 0.6255 | MSE: 0.6771
# Run 3 | Epoch 080 | Train Loss: 0.702452 | Val Loss: 0.675453 | MAE: 0.6243 | MSE: 0.6755
# Run 3 | Epoch 081 | Train Loss: 0.701166 | Val Loss: 0.674836 | MAE: 0.6240 | MSE: 0.6748
# Run 3 | Epoch 082 | Train Loss: 0.699441 | Val Loss: 0.673272 | MAE: 0.6233 | MSE: 0.6733
# Run 3 | Epoch 083 | Train Loss: 0.697721 | Val Loss: 0.672631 | MAE: 0.6228 | MSE: 0.6726
# Run 3 | Epoch 084 | Train Loss: 0.696457 | Val Loss: 0.672157 | MAE: 0.6210 | MSE: 0.6722
# Run 3 | Epoch 085 | Train Loss: 0.695490 | Val Loss: 0.670782 | MAE: 0.6193 | MSE: 0.6708
# Run 3 | Epoch 086 | Train Loss: 0.693564 | Val Loss: 0.668134 | MAE: 0.6194 | MSE: 0.6681
# Run 3 | Epoch 087 | Train Loss: 0.692596 | Val Loss: 0.670668 | MAE: 0.6198 | MSE: 0.6707
# Run 3 | Epoch 088 | Train Loss: 0.691161 | Val Loss: 0.665391 | MAE: 0.6177 | MSE: 0.6654
# Run 3 | Epoch 089 | Train Loss: 0.689612 | Val Loss: 0.667375 | MAE: 0.6185 | MSE: 0.6674
# Run 3 | Epoch 090 | Train Loss: 0.689589 | Val Loss: 0.663982 | MAE: 0.6160 | MSE: 0.6640
# Run 3 | Epoch 091 | Train Loss: 0.687240 | Val Loss: 0.662473 | MAE: 0.6156 | MSE: 0.6625
# Run 3 | Epoch 092 | Train Loss: 0.685365 | Val Loss: 0.662409 | MAE: 0.6152 | MSE: 0.6624
# Run 3 | Epoch 093 | Train Loss: 0.684420 | Val Loss: 0.664009 | MAE: 0.6146 | MSE: 0.6640
# Run 3 | Epoch 094 | Train Loss: 0.683793 | Val Loss: 0.661412 | MAE: 0.6150 | MSE: 0.6614
# Run 3 | Epoch 095 | Train Loss: 0.681225 | Val Loss: 0.658722 | MAE: 0.6134 | MSE: 0.6587
# Run 3 | Epoch 096 | Train Loss: 0.679790 | Val Loss: 0.661002 | MAE: 0.6140 | MSE: 0.6610
# Run 3 | Epoch 097 | Train Loss: 0.678195 | Val Loss: 0.654448 | MAE: 0.6103 | MSE: 0.6544
# Run 3 | Epoch 098 | Train Loss: 0.676935 | Val Loss: 0.660060 | MAE: 0.6138 | MSE: 0.6601
# Run 3 | Epoch 099 | Train Loss: 0.674782 | Val Loss: 0.652598 | MAE: 0.6088 | MSE: 0.6526
# Run 3 | Epoch 100 | Train Loss: 0.673084 | Val Loss: 0.649145 | MAE: 0.6080 | MSE: 0.6491
#
# === Run 4 ===
# Run 4 | Epoch 001 | Train Loss: 1.971523 | Val Loss: 1.894735 | MAE: 1.0327 | MSE: 1.8947
# Run 4 | Epoch 002 | Train Loss: 1.588132 | Val Loss: 1.097446 | MAE: 0.7756 | MSE: 1.0974
# Run 4 | Epoch 003 | Train Loss: 1.068885 | Val Loss: 0.874424 | MAE: 0.7278 | MSE: 0.8744
# Run 4 | Epoch 004 | Train Loss: 0.955149 | Val Loss: 0.838087 | MAE: 0.7233 | MSE: 0.8381
# Run 4 | Epoch 005 | Train Loss: 0.923518 | Val Loss: 0.828770 | MAE: 0.7234 | MSE: 0.8288
# Run 4 | Epoch 006 | Train Loss: 0.906272 | Val Loss: 0.824996 | MAE: 0.7243 | MSE: 0.8250
# Run 4 | Epoch 007 | Train Loss: 0.895151 | Val Loss: 0.822829 | MAE: 0.7257 | MSE: 0.8228
# Run 4 | Epoch 008 | Train Loss: 0.886920 | Val Loss: 0.821818 | MAE: 0.7263 | MSE: 0.8218
# Run 4 | Epoch 009 | Train Loss: 0.880531 | Val Loss: 0.821073 | MAE: 0.7270 | MSE: 0.8211
# Run 4 | Epoch 010 | Train Loss: 0.875350 | Val Loss: 0.820587 | MAE: 0.7276 | MSE: 0.8206
# Run 4 | Epoch 011 | Train Loss: 0.870870 | Val Loss: 0.820233 | MAE: 0.7281 | MSE: 0.8202
# Run 4 | Epoch 012 | Train Loss: 0.867322 | Val Loss: 0.819980 | MAE: 0.7285 | MSE: 0.8200
# Run 4 | Epoch 013 | Train Loss: 0.864277 | Val Loss: 0.819879 | MAE: 0.7282 | MSE: 0.8199
# Run 4 | Epoch 014 | Train Loss: 0.861551 | Val Loss: 0.819630 | MAE: 0.7295 | MSE: 0.8196
# Run 4 | Epoch 015 | Train Loss: 0.859429 | Val Loss: 0.819505 | MAE: 0.7306 | MSE: 0.8195
# Run 4 | Epoch 016 | Train Loss: 0.857419 | Val Loss: 0.819435 | MAE: 0.7306 | MSE: 0.8194
# Run 4 | Epoch 017 | Train Loss: 0.855576 | Val Loss: 0.819374 | MAE: 0.7301 | MSE: 0.8194
# Run 4 | Epoch 018 | Train Loss: 0.854044 | Val Loss: 0.819377 | MAE: 0.7319 | MSE: 0.8194
# Run 4 | Epoch 019 | Train Loss: 0.852509 | Val Loss: 0.819330 | MAE: 0.7320 | MSE: 0.8193
# Run 4 | Epoch 020 | Train Loss: 0.851275 | Val Loss: 0.819272 | MAE: 0.7314 | MSE: 0.8193
# Run 4 | Epoch 021 | Train Loss: 0.850068 | Val Loss: 0.819226 | MAE: 0.7321 | MSE: 0.8192
# Run 4 | Epoch 022 | Train Loss: 0.848940 | Val Loss: 0.819059 | MAE: 0.7312 | MSE: 0.8191
# Run 4 | Epoch 023 | Train Loss: 0.847889 | Val Loss: 0.819019 | MAE: 0.7314 | MSE: 0.8190
# Run 4 | Epoch 024 | Train Loss: 0.846807 | Val Loss: 0.819002 | MAE: 0.7320 | MSE: 0.8190
# Run 4 | Epoch 025 | Train Loss: 0.846043 | Val Loss: 0.818856 | MAE: 0.7319 | MSE: 0.8189
# Run 4 | Epoch 026 | Train Loss: 0.845173 | Val Loss: 0.818866 | MAE: 0.7324 | MSE: 0.8189
# Run 4 | Epoch 027 | Train Loss: 0.844202 | Val Loss: 0.818780 | MAE: 0.7325 | MSE: 0.8188
# Run 4 | Epoch 028 | Train Loss: 0.843624 | Val Loss: 0.818595 | MAE: 0.7321 | MSE: 0.8186
# Run 4 | Epoch 029 | Train Loss: 0.842781 | Val Loss: 0.818365 | MAE: 0.7315 | MSE: 0.8184
# Run 4 | Epoch 030 | Train Loss: 0.842212 | Val Loss: 0.818280 | MAE: 0.7322 | MSE: 0.8183
# Run 4 | Epoch 031 | Train Loss: 0.841374 | Val Loss: 0.818139 | MAE: 0.7326 | MSE: 0.8181
# Run 4 | Epoch 032 | Train Loss: 0.840650 | Val Loss: 0.817940 | MAE: 0.7329 | MSE: 0.8179
# Run 4 | Epoch 033 | Train Loss: 0.839769 | Val Loss: 0.817361 | MAE: 0.7317 | MSE: 0.8174
# Run 4 | Epoch 034 | Train Loss: 0.839079 | Val Loss: 0.816739 | MAE: 0.7299 | MSE: 0.8167
# Run 4 | Epoch 035 | Train Loss: 0.838201 | Val Loss: 0.816581 | MAE: 0.7324 | MSE: 0.8166
# Run 4 | Epoch 036 | Train Loss: 0.837311 | Val Loss: 0.815428 | MAE: 0.7300 | MSE: 0.8154
# Run 4 | Epoch 037 | Train Loss: 0.836212 | Val Loss: 0.814648 | MAE: 0.7308 | MSE: 0.8146
# Run 4 | Epoch 038 | Train Loss: 0.834829 | Val Loss: 0.813363 | MAE: 0.7303 | MSE: 0.8134
# Run 4 | Epoch 039 | Train Loss: 0.833334 | Val Loss: 0.811445 | MAE: 0.7280 | MSE: 0.8114
# Run 4 | Epoch 040 | Train Loss: 0.831336 | Val Loss: 0.808998 | MAE: 0.7257 | MSE: 0.8090
# Run 4 | Epoch 041 | Train Loss: 0.829085 | Val Loss: 0.806657 | MAE: 0.7266 | MSE: 0.8067
# Run 4 | Epoch 042 | Train Loss: 0.826068 | Val Loss: 0.802690 | MAE: 0.7229 | MSE: 0.8027
# Run 4 | Epoch 043 | Train Loss: 0.822693 | Val Loss: 0.799568 | MAE: 0.7215 | MSE: 0.7996
# Run 4 | Epoch 044 | Train Loss: 0.819582 | Val Loss: 0.794649 | MAE: 0.7174 | MSE: 0.7946
# Run 4 | Epoch 045 | Train Loss: 0.815435 | Val Loss: 0.790619 | MAE: 0.7155 | MSE: 0.7906
# Run 4 | Epoch 046 | Train Loss: 0.812163 | Val Loss: 0.787100 | MAE: 0.7123 | MSE: 0.7871
# Run 4 | Epoch 047 | Train Loss: 0.809142 | Val Loss: 0.784547 | MAE: 0.7123 | MSE: 0.7845
# Run 4 | Epoch 048 | Train Loss: 0.806653 | Val Loss: 0.781765 | MAE: 0.7094 | MSE: 0.7818
# Run 4 | Epoch 049 | Train Loss: 0.804467 | Val Loss: 0.779351 | MAE: 0.7076 | MSE: 0.7794
# Run 4 | Epoch 050 | Train Loss: 0.801893 | Val Loss: 0.776757 | MAE: 0.7048 | MSE: 0.7768
# Run 4 | Epoch 051 | Train Loss: 0.800559 | Val Loss: 0.776713 | MAE: 0.7051 | MSE: 0.7767
# Run 4 | Epoch 052 | Train Loss: 0.798438 | Val Loss: 0.772733 | MAE: 0.7018 | MSE: 0.7727
# Run 4 | Epoch 053 | Train Loss: 0.795207 | Val Loss: 0.769940 | MAE: 0.6998 | MSE: 0.7699
# Run 4 | Epoch 054 | Train Loss: 0.792838 | Val Loss: 0.767168 | MAE: 0.6986 | MSE: 0.7672
# Run 4 | Epoch 055 | Train Loss: 0.790063 | Val Loss: 0.764264 | MAE: 0.6958 | MSE: 0.7643
# Run 4 | Epoch 056 | Train Loss: 0.787214 | Val Loss: 0.761195 | MAE: 0.6938 | MSE: 0.7612
# Run 4 | Epoch 057 | Train Loss: 0.784220 | Val Loss: 0.758321 | MAE: 0.6904 | MSE: 0.7583
# Run 4 | Epoch 058 | Train Loss: 0.781144 | Val Loss: 0.755333 | MAE: 0.6897 | MSE: 0.7553
# Run 4 | Epoch 059 | Train Loss: 0.778240 | Val Loss: 0.752205 | MAE: 0.6882 | MSE: 0.7522
# Run 4 | Epoch 060 | Train Loss: 0.774981 | Val Loss: 0.748026 | MAE: 0.6829 | MSE: 0.7480
# Run 4 | Epoch 061 | Train Loss: 0.771193 | Val Loss: 0.742442 | MAE: 0.6801 | MSE: 0.7424
# Run 4 | Epoch 062 | Train Loss: 0.764557 | Val Loss: 0.731020 | MAE: 0.6718 | MSE: 0.7310
# Run 4 | Epoch 063 | Train Loss: 0.751076 | Val Loss: 0.711322 | MAE: 0.6557 | MSE: 0.7113
# Run 4 | Epoch 064 | Train Loss: 0.736520 | Val Loss: 0.697537 | MAE: 0.6446 | MSE: 0.6975
# Run 4 | Epoch 065 | Train Loss: 0.726968 | Val Loss: 0.696972 | MAE: 0.6409 | MSE: 0.6970
# Run 4 | Epoch 066 | Train Loss: 0.721831 | Val Loss: 0.687484 | MAE: 0.6354 | MSE: 0.6875
# Run 4 | Epoch 067 | Train Loss: 0.717213 | Val Loss: 0.689596 | MAE: 0.6337 | MSE: 0.6896
# Run 4 | Epoch 068 | Train Loss: 0.788010 | Val Loss: 0.755815 | MAE: 0.6800 | MSE: 0.7558
# Run 4 | Epoch 069 | Train Loss: 0.772141 | Val Loss: 0.746155 | MAE: 0.6787 | MSE: 0.7462
# Run 4 | Epoch 070 | Train Loss: 0.765179 | Val Loss: 0.740712 | MAE: 0.6757 | MSE: 0.7407
# Run 4 | Epoch 071 | Train Loss: 0.760768 | Val Loss: 0.736000 | MAE: 0.6730 | MSE: 0.7360
# Run 4 | Epoch 072 | Train Loss: 0.756123 | Val Loss: 0.731770 | MAE: 0.6701 | MSE: 0.7318
# Run 4 | Epoch 073 | Train Loss: 0.751922 | Val Loss: 0.726801 | MAE: 0.6675 | MSE: 0.7268
# Run 4 | Epoch 074 | Train Loss: 0.747630 | Val Loss: 0.722799 | MAE: 0.6636 | MSE: 0.7228
# Run 4 | Epoch 075 | Train Loss: 0.744223 | Val Loss: 0.719102 | MAE: 0.6610 | MSE: 0.7191
# Run 4 | Epoch 076 | Train Loss: 0.740851 | Val Loss: 0.715974 | MAE: 0.6584 | MSE: 0.7160
# Early stopping at epoch 76
#
# === Run 5 ===
# Run 5 | Epoch 001 | Train Loss: 1.967049 | Val Loss: 1.878954 | MAE: 1.0244 | MSE: 1.8790
# Run 5 | Epoch 002 | Train Loss: 1.570114 | Val Loss: 1.093187 | MAE: 0.7770 | MSE: 1.0932
# Run 5 | Epoch 003 | Train Loss: 1.071595 | Val Loss: 0.876285 | MAE: 0.7285 | MSE: 0.8763
# Run 5 | Epoch 004 | Train Loss: 0.957926 | Val Loss: 0.839335 | MAE: 0.7235 | MSE: 0.8393
# Run 5 | Epoch 005 | Train Loss: 0.924856 | Val Loss: 0.829651 | MAE: 0.7232 | MSE: 0.8297
# Run 5 | Epoch 006 | Train Loss: 0.907334 | Val Loss: 0.825085 | MAE: 0.7250 | MSE: 0.8251
# Run 5 | Epoch 007 | Train Loss: 0.895977 | Val Loss: 0.823289 | MAE: 0.7253 | MSE: 0.8233
# Run 5 | Epoch 008 | Train Loss: 0.887441 | Val Loss: 0.821969 | MAE: 0.7263 | MSE: 0.8220
# Run 5 | Epoch 009 | Train Loss: 0.880920 | Val Loss: 0.821316 | MAE: 0.7264 | MSE: 0.8213
# Run 5 | Epoch 010 | Train Loss: 0.875608 | Val Loss: 0.820610 | MAE: 0.7275 | MSE: 0.8206
# Run 5 | Epoch 011 | Train Loss: 0.871434 | Val Loss: 0.820182 | MAE: 0.7283 | MSE: 0.8202
# Run 5 | Epoch 012 | Train Loss: 0.867579 | Val Loss: 0.819958 | MAE: 0.7286 | MSE: 0.8200
# Run 5 | Epoch 013 | Train Loss: 0.864640 | Val Loss: 0.819664 | MAE: 0.7306 | MSE: 0.8197
# Run 5 | Epoch 014 | Train Loss: 0.861889 | Val Loss: 0.819571 | MAE: 0.7295 | MSE: 0.8196
# Run 5 | Epoch 015 | Train Loss: 0.859604 | Val Loss: 0.819456 | MAE: 0.7298 | MSE: 0.8195
# Run 5 | Epoch 016 | Train Loss: 0.857640 | Val Loss: 0.819417 | MAE: 0.7308 | MSE: 0.8194
# Run 5 | Epoch 017 | Train Loss: 0.855983 | Val Loss: 0.819289 | MAE: 0.7310 | MSE: 0.8193
# Run 5 | Epoch 018 | Train Loss: 0.854198 | Val Loss: 0.819337 | MAE: 0.7322 | MSE: 0.8193
# Run 5 | Epoch 019 | Train Loss: 0.852593 | Val Loss: 0.819145 | MAE: 0.7315 | MSE: 0.8191
# Run 5 | Epoch 020 | Train Loss: 0.851223 | Val Loss: 0.819067 | MAE: 0.7316 | MSE: 0.8191
# Run 5 | Epoch 021 | Train Loss: 0.850058 | Val Loss: 0.819075 | MAE: 0.7319 | MSE: 0.8191
# Run 5 | Epoch 022 | Train Loss: 0.848965 | Val Loss: 0.819016 | MAE: 0.7322 | MSE: 0.8190
# Run 5 | Epoch 023 | Train Loss: 0.847906 | Val Loss: 0.818834 | MAE: 0.7315 | MSE: 0.8188
# Run 5 | Epoch 024 | Train Loss: 0.846924 | Val Loss: 0.818700 | MAE: 0.7317 | MSE: 0.8187
# Run 5 | Epoch 025 | Train Loss: 0.845952 | Val Loss: 0.818641 | MAE: 0.7313 | MSE: 0.8186
# Run 5 | Epoch 026 | Train Loss: 0.845081 | Val Loss: 0.818682 | MAE: 0.7329 | MSE: 0.8187
# Run 5 | Epoch 027 | Train Loss: 0.844285 | Val Loss: 0.818249 | MAE: 0.7305 | MSE: 0.8182
# Run 5 | Epoch 028 | Train Loss: 0.843325 | Val Loss: 0.818273 | MAE: 0.7328 | MSE: 0.8183
# Run 5 | Epoch 029 | Train Loss: 0.842581 | Val Loss: 0.817855 | MAE: 0.7316 | MSE: 0.8179
# Run 5 | Epoch 030 | Train Loss: 0.841775 | Val Loss: 0.817825 | MAE: 0.7334 | MSE: 0.8178
# Run 5 | Epoch 031 | Train Loss: 0.840739 | Val Loss: 0.817021 | MAE: 0.7324 | MSE: 0.8170
# Run 5 | Epoch 032 | Train Loss: 0.839652 | Val Loss: 0.816023 | MAE: 0.7307 | MSE: 0.8160
# Run 5 | Epoch 033 | Train Loss: 0.838451 | Val Loss: 0.814900 | MAE: 0.7299 | MSE: 0.8149
# Run 5 | Epoch 034 | Train Loss: 0.836850 | Val Loss: 0.813579 | MAE: 0.7305 | MSE: 0.8136
# Run 5 | Epoch 035 | Train Loss: 0.835093 | Val Loss: 0.811397 | MAE: 0.7281 | MSE: 0.8114
# Run 5 | Epoch 036 | Train Loss: 0.832667 | Val Loss: 0.808730 | MAE: 0.7272 | MSE: 0.8087
# Run 5 | Epoch 037 | Train Loss: 0.829503 | Val Loss: 0.805040 | MAE: 0.7251 | MSE: 0.8050
# Run 5 | Epoch 038 | Train Loss: 0.826062 | Val Loss: 0.800926 | MAE: 0.7215 | MSE: 0.8009
# Run 5 | Epoch 039 | Train Loss: 0.822507 | Val Loss: 0.797028 | MAE: 0.7203 | MSE: 0.7970
# Run 5 | Epoch 040 | Train Loss: 0.818979 | Val Loss: 0.793508 | MAE: 0.7174 | MSE: 0.7935
# Run 5 | Epoch 041 | Train Loss: 0.815646 | Val Loss: 0.789492 | MAE: 0.7145 | MSE: 0.7895
# Run 5 | Epoch 042 | Train Loss: 0.813035 | Val Loss: 0.788359 | MAE: 0.7118 | MSE: 0.7884
# Run 5 | Epoch 043 | Train Loss: 0.811150 | Val Loss: 0.785246 | MAE: 0.7104 | MSE: 0.7852
# Run 5 | Epoch 044 | Train Loss: 0.808219 | Val Loss: 0.782941 | MAE: 0.7105 | MSE: 0.7829
# Run 5 | Epoch 045 | Train Loss: 0.806294 | Val Loss: 0.780706 | MAE: 0.7084 | MSE: 0.7807
# Run 5 | Epoch 046 | Train Loss: 0.804111 | Val Loss: 0.779477 | MAE: 0.7075 | MSE: 0.7795
# Run 5 | Epoch 047 | Train Loss: 0.802345 | Val Loss: 0.776758 | MAE: 0.7057 | MSE: 0.7768
# Run 5 | Epoch 048 | Train Loss: 0.799851 | Val Loss: 0.774614 | MAE: 0.7045 | MSE: 0.7746
# Run 5 | Epoch 049 | Train Loss: 0.797775 | Val Loss: 0.771883 | MAE: 0.7017 | MSE: 0.7719
# Run 5 | Epoch 050 | Train Loss: 0.795271 | Val Loss: 0.769343 | MAE: 0.6996 | MSE: 0.7693
# Run 5 | Epoch 051 | Train Loss: 0.792465 | Val Loss: 0.766759 | MAE: 0.6989 | MSE: 0.7668
# Run 5 | Epoch 052 | Train Loss: 0.790075 | Val Loss: 0.763479 | MAE: 0.6956 | MSE: 0.7635
# Run 5 | Epoch 053 | Train Loss: 0.787191 | Val Loss: 0.760487 | MAE: 0.6933 | MSE: 0.7605
# Run 5 | Epoch 054 | Train Loss: 0.783818 | Val Loss: 0.757076 | MAE: 0.6915 | MSE: 0.7571
# Run 5 | Epoch 055 | Train Loss: 0.780434 | Val Loss: 0.753170 | MAE: 0.6887 | MSE: 0.7532
# Run 5 | Epoch 056 | Train Loss: 0.776637 | Val Loss: 0.748056 | MAE: 0.6854 | MSE: 0.7481
# Run 5 | Epoch 057 | Train Loss: 0.770846 | Val Loss: 0.735740 | MAE: 0.6769 | MSE: 0.7357
# Run 5 | Epoch 058 | Train Loss: 0.757748 | Val Loss: 0.718292 | MAE: 0.6616 | MSE: 0.7183
# Run 5 | Epoch 059 | Train Loss: 0.754875 | Val Loss: 0.723358 | MAE: 0.6673 | MSE: 0.7234
# Run 5 | Epoch 060 | Train Loss: 0.750320 | Val Loss: 0.723587 | MAE: 0.6587 | MSE: 0.7236
# Run 5 | Epoch 061 | Train Loss: 0.747395 | Val Loss: 0.708933 | MAE: 0.6524 | MSE: 0.7089
# Run 5 | Epoch 062 | Train Loss: 0.736124 | Val Loss: 0.699935 | MAE: 0.6450 | MSE: 0.6999
# Run 5 | Epoch 063 | Train Loss: 0.729217 | Val Loss: 0.690741 | MAE: 0.6381 | MSE: 0.6907
# Run 5 | Epoch 064 | Train Loss: 0.722068 | Val Loss: 0.687895 | MAE: 0.6346 | MSE: 0.6879
# Run 5 | Epoch 065 | Train Loss: 0.718895 | Val Loss: 0.687814 | MAE: 0.6338 | MSE: 0.6878
# Run 5 | Epoch 066 | Train Loss: 0.716401 | Val Loss: 0.684818 | MAE: 0.6304 | MSE: 0.6848
# Run 5 | Epoch 067 | Train Loss: 0.714704 | Val Loss: 0.680132 | MAE: 0.6276 | MSE: 0.6801
# Run 5 | Epoch 068 | Train Loss: 0.713812 | Val Loss: 0.680040 | MAE: 0.6272 | MSE: 0.6800
# Run 5 | Epoch 069 | Train Loss: 0.711303 | Val Loss: 0.682935 | MAE: 0.6300 | MSE: 0.6829
# Run 5 | Epoch 070 | Train Loss: 0.711405 | Val Loss: 0.680229 | MAE: 0.6300 | MSE: 0.6802
# Run 5 | Epoch 071 | Train Loss: 0.709006 | Val Loss: 0.680462 | MAE: 0.6274 | MSE: 0.6805
# Run 5 | Epoch 072 | Train Loss: 0.709174 | Val Loss: 0.715654 | MAE: 0.6479 | MSE: 0.7157
# Run 5 | Epoch 073 | Train Loss: 0.713556 | Val Loss: 0.681066 | MAE: 0.6313 | MSE: 0.6811
# Run 5 | Epoch 074 | Train Loss: 0.708100 | Val Loss: 0.680498 | MAE: 0.6285 | MSE: 0.6805
# Run 5 | Epoch 075 | Train Loss: 0.705770 | Val Loss: 0.677496 | MAE: 0.6281 | MSE: 0.6775
# Run 5 | Epoch 076 | Train Loss: 0.704183 | Val Loss: 0.675772 | MAE: 0.6254 | MSE: 0.6758
# Run 5 | Epoch 077 | Train Loss: 0.701732 | Val Loss: 0.676649 | MAE: 0.6238 | MSE: 0.6766
# Run 5 | Epoch 078 | Train Loss: 0.744831 | Val Loss: 0.860658 | MAE: 0.7261 | MSE: 0.8607
# Run 5 | Epoch 079 | Train Loss: 0.809646 | Val Loss: 0.755895 | MAE: 0.6861 | MSE: 0.7559
# Run 5 | Epoch 080 | Train Loss: 0.771119 | Val Loss: 0.738508 | MAE: 0.6726 | MSE: 0.7385
# Run 5 | Epoch 081 | Train Loss: 0.758368 | Val Loss: 0.728888 | MAE: 0.6651 | MSE: 0.7289
# Run 5 | Epoch 082 | Train Loss: 0.751375 | Val Loss: 0.724109 | MAE: 0.6612 | MSE: 0.7241
# Run 5 | Epoch 083 | Train Loss: 0.746330 | Val Loss: 0.719324 | MAE: 0.6568 | MSE: 0.7193
# Run 5 | Epoch 084 | Train Loss: 0.741218 | Val Loss: 0.712265 | MAE: 0.6512 | MSE: 0.7123
# Run 5 | Epoch 085 | Train Loss: 0.735038 | Val Loss: 0.703980 | MAE: 0.6470 | MSE: 0.7040
# Run 5 | Epoch 086 | Train Loss: 0.726890 | Val Loss: 0.696187 | MAE: 0.6414 | MSE: 0.6962
# Early stopping at epoch 86
#
# === Final Evaluation over 5 Runs ===
# MAE: mean = 0.6244, std = 0.0090
# MSE: mean = 0.6744, std = 0.0132

# %%
max_len = max(len(x) for x in all_train_losses)

def pad(arr):
    return np.array([x + [x[-1]] * (max_len - len(x)) for x in arr])

avg_train = pad(all_train_losses).mean(axis=0)
avg_val   = pad(all_val_losses).mean(axis=0)

plt.figure(figsize=(8, 5))
plt.plot(avg_train, label="Avg Train MSE")
plt.plot(avg_val, label="Avg Val MSE")
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")
plt.title("Average Loss over 5 Runs (BiLSTM 90→365)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("output/pics/loss/pred365/avg_loss_over_5_runs.png", dpi=300)
plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error
import torch

gts_hour = y_test 
gts_day = gts_hour.reshape(-1, 365, 24).mean(axis=2) 

# 缓存所有模型预测
all_model_preds_day = []

for run in range(1, 6):
    print(f"\n=== Run {run} Evaluation ===")

    # 加载模型

    model = BiLSTM_Deep(
        input_size=7,
        hidden_size=256,
        output_len=8760,
        num_layers=2,
        dropout=0.3
    ).to(device)
    model.load_state_dict(torch.load(f"output/models/pred365/run_{run}.pth"))
    model.eval()

    # 推理
    test_ds = torch.utils.data.TensorDataset(
        torch.tensor(X_test, dtype=torch.float32),
        torch.tensor(y_test, dtype=torch.float32)
    )
    test_loader = torch.utils.data.DataLoader(test_ds, batch_size=256, shuffle=False)

    preds = []
    with torch.no_grad():
        for xb, _ in test_loader:
            xb = xb.to(device)
            pred = model(xb).cpu().numpy()
            preds.append(pred)
    preds = np.concatenate(preds, axis=0)  
    preds_day = preds.reshape(-1, 365, 24).mean(axis=2)  

    all_model_preds_day.append(preds_day)  # 保留每组 day 级预测

    # ==== 多样本评估 ====
    sample_ids = [5 * (run - 1) + i for i in range(5)]  # 每组画 5 个样本
    mae_list = []
    mse_list = []

    for idx in sample_ids:
        gt = gts_day[idx]
        pred = preds_day[idx]
        mae = mean_absolute_error(gt, pred)
        mse = mean_squared_error(gt, pred)
        mae_list.append(mae)
        mse_list.append(mse)

        # 图保存
        plt.figure(figsize=(10, 4.5))
        plt.plot(gt, label="Ground Truth", linewidth=2)
        plt.plot(pred, label="Prediction", linewidth=2)
        plt.xlabel("Day")
        plt.ylabel("Avg Power (kW)")
        plt.title(f"Run {run} - Sample {idx} | MAE: {mae:.4f}, MSE: {mse:.4f}")
        plt.xticks(np.arange(0, 366, 5), labels=[str(i+1) for i in range(0, 366, 5)])
        plt.grid(True)
        plt.legend()
        plt.tight_layout()
        plt.savefig(f"output/pics/comparison/pred365/run_{run}_sample_{idx}.png", dpi=300)
        plt.close()

    # 打印指标
    print(f"[Run {run}] MAE (day): mean = {np.mean(mae_list):.4f}, std = {np.std(mae_list):.4f}")
    print(f"[Run {run}] MSE (day): mean = {np.mean(mse_list):.4f}, std = {np.std(mse_list):.4f}")

# ==== 平均预测绘图 ====
print("\n=== Averaged Prediction over 5 Models ===")
for i in range(5):  # 样本编号：0~4
    idx = i * 5
    gt = gts_day[idx]

    preds_across_models = [preds_day[idx] for preds_day in all_model_preds_day]
    avg_pred = np.mean(preds_across_models, axis=0)

    mae = mean_absolute_error(gt, avg_pred)
    mse = mean_squared_error(gt, avg_pred)

    plt.figure(figsize=(10, 4.5))
    plt.plot(gt, label="Ground Truth", linewidth=2)
    plt.plot(avg_pred, label="Avg Prediction", linewidth=2)
    plt.xlabel("Day")
    plt.ylabel("Avg Power (kW)")
    plt.title(f"Averaged Prediction - Sample {idx} | MAE: {mae:.4f}, MSE: {mse:.4f}")
    plt.xticks(np.arange(0, 366, 5), labels=[str(i+1) for i in range(0, 366, 5)])
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.savefig(f"output/pics/comparison/pred365/avg_sample_{idx}.png", dpi=300)
    plt.close()
# Out:
# === Run 1 Evaluation ===
# /tmp/ipykernel_371015/3284468314.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"output/models/pred365/run_{run}.pth"))
# [Run 1] MAE (day): mean = 0.2133, std = 0.0010
# [Run 1] MSE (day): mean = 0.0812, std = 0.0028
#
# === Run 2 Evaluation ===
# /tmp/ipykernel_371015/3284468314.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"output/models/pred365/run_{run}.pth"))
# [Run 2] MAE (day): mean = 0.2179, std = 0.0014
# [Run 2] MSE (day): mean = 0.0859, std = 0.0006
#
# === Run 3 Evaluation ===
# /tmp/ipykernel_371015/3284468314.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"output/models/pred365/run_{run}.pth"))
# [Run 3] MAE (day): mean = 0.2243, std = 0.0023
# [Run 3] MSE (day): mean = 0.0871, std = 0.0016
#
# === Run 4 Evaluation ===
# /tmp/ipykernel_371015/3284468314.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"output/models/pred365/run_{run}.pth"))
# [Run 4] MAE (day): mean = 0.2015, std = 0.0042
# [Run 4] MSE (day): mean = 0.0736, std = 0.0035
#
# === Run 5 Evaluation ===
# /tmp/ipykernel_371015/3284468314.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"output/models/pred365/run_{run}.pth"))
# [Run 5] MAE (day): mean = 0.2108, std = 0.0041
# [Run 5] MSE (day): mean = 0.0771, std = 0.0032
#
# === Averaged Prediction over 5 Models ===
